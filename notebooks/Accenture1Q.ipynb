# %%
import json

with open("data/cuad/train_separate_questions.json") as f:
    train = json.load(f)

print(train.keys())
print(len(train["data"]))   # expect 408
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import json
#       2
# ----> 3 with open("data/cuad/train_separate_questions.json") as f:
#       4     train = json.load(f)
#       5
#       6 print(train.keys())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/cuad/train_separate_questions.json'
